# %% [markdown]
# ### This notebook presents the application of three diferent NER algorithms: StanfordNER, Spacy and flair. They are evaluated by ability of recognize persons and locations of text sample.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter, defaultdict

# %%
import spacy

import nltk
from nltk.tag.stanford import StanfordNERTagger as NERTagger

from flair.data import Sentence
from flair.models import SequenceTagger
from segtok.segmenter import split_single

import stanfordnlp
from spacy_stanfordnlp import StanfordNLPLanguage

# %% [markdown]
# # Data

# %% [markdown]
# The first chapter of harry potter and the philosopher's stone is used to evaluate the performance of different NER algorithms

# %%
with open('data/harry.txt', encoding='UTF-8') as f:
    ttext = f.read()

# %% [markdown]
# # Comparison

# %%
person_outputs = {}

# %% [markdown]
# ## spaCy

# %%
lib_key = 'spacy'
person_outputs[lib_key] = []

# %%
nlp = spacy.load('en')

for doc in nlp.pipe([ttext], n_threads=1, batch_size=1):
    display(doc.ents)
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            person_outputs['spacy'].append(ent)
# Out:
# (Dursley,
#  number four,
#  Privet Drive,
#  Dursley,
#  Grunnings,
#  Dursley,
#  Dursleys,
#  Dudley,
#  Dursleys,
#  Potters,
#  Dursley,
#  several years,
#  Dursley,
#  Potters,
#  Potters,
#  Dursley,
#  Tuesday,
#  Dursley,
#  Dursley,
#  half past eight,
#  Dursley,
#  Dursley,
#  Dudley,
#  Dudley,
#  Dursley,
#  number four,
#  first,
#  second,
#  Dursley,
#  Privet,
#  Dursley,
#  Dursley,
#  Privet Drive,
#  Dursley,
#  that day,
#  Dursley,
#  Dursley,
#  Dursley,
#  a few minutes later,
#  Dursley,
#  Grunnings,
#  Dursley,
#  ninth,
#  that morning,
#  nighttime,
#  Dursley,
#  five,
#  baker,
#  The Potters,
#  Harry,
#  Dursley,
#  Harry,
#  Harry,
#  Harvey,
#  Harold,
#  Dursley,
#  that afternoon,
#  five o'clock,
#  a few seconds,
#  Dursley,
#  today,
#  last!Even Muggles,
#  Dursley,
#  Dursley,
#  Muggle,
#  four,
#  Shoo,
#  Dursley,
#  Dursley,
#  Dursley,
#  normal day,
#  Next Door,
#  Dudley,
#  Dursley,
#  Dudley,
#  today,
#  hunt at night,
#  daylight,
#  hundreds,
#  Jim McGuffin,
#  tonight,
#  Jim,
#  Ted,
#  today,
#  Kent,
#  Yorkshire,
#  Dundee,
#  yesterday,
#  Bonfire Night,
#  next week,
#  tonight,
#  Dursley,
#  Britain,
#  Dursley,
#  two,
#  Petunia,
#  Dursley,
#  Dursley,
#  today,
#  Dursley,
#  Dursley,
#  Dursley,
#  Dudley,
#  Dursley,
#  again?Howard,
#  Harry,
#  Dursley,
#  Dursley,
#  Dursley,
#  Privet Drive,
#  Dursley,
#  Dursley,
#  Dursley,
#  Petunia,
#  Petunia,
#  Dursley,
#  Privet,
#  two,
#  nearly
#  midnight,
#  Privet Drive,
#  half-moon,
#  Albus Dumbledore,
#  Albus Dumbledore,
#  Twelve,
#  the Put-Outer,
#  two,
#  Dursley,
#  Dumbledore,
#  four,
#  Item,
#  Item,
#  McGonagall,
#  Item,
#  quien,
#  Item,
#  McGonagall,
#  All day,
#  the day,
#  dozen,
#  McGonagall,
#  the day,
#  Item,
#  Flocks,
#  Kent,
#  Dedalus Diggle,
#  Dumbledore,
#  eleven years,
#  McGonagall,
#  Muggle,
#  Dumbledore,
#  Item,
#  Muggles,
#  Dumbledore,
#  Dumbledore,
#  Muggle,
#  McGonagall,
#  Este,
#  Professor,
#  eleven years,
#  Voldemort,
#  McGonagall,
#  Dumbledore,
#  quien,
#  two,
#  Voldemort,
#  McGonagall,
#  half,
#  half,
#  one,
#  Voldemort,
#  Dumbledore,
#  Voldemort,
#  Pomfrey,
#  McGonagall,
#  Dumbledore,
#  que,
#  Item,
#  McGonagall,
#  Discuss,
#  Dumbledore,
#  Item,
#  Item,
#  Dumbledore,
#  Item,
#  Dumbledore,
#  last night,
#  Voldemort,
#  Godric,
#  Hollow,
#  Potters,
#  Lily,
#  James Potter,
#  Dumbledore,
#  McGonagall,
#  Lily,
#  James,
#  Item,
#  Item,
#  Dumbledore,
#  McGonagall,
#  the Potter's They are, Harry,
#  Harry Potter,
#  Voldemort,
#  Dumbledore,
#  McGonagall,
#  Harry,
#  Dumbledore,
#  McGonagall,
#  Dumbledore,
#  Item,
#  Item,
#  twelve,
#  Dumbledore,
#  Item,
#  Hagrid,
#  Item,
#  quien,
#  McGonagall,
#  Harry,
#  Familia,
#  quien,
#  McGonagall,
#  number four,
#  two,
#  quien,
#  Harry Potter,
#  Dumbledore,
#  McGonagall,
#  today,
#  day,
#  Harry,
#  Dumbledore,
#  Item,
#  McGonagall,
#  Dumbledore,
#  Harry underneath Item,
#  Hagrid,
#  Dumbledore,
#  McGonagall,
#  eleven,
#  Item,
#  Item,
#  Item,
#  at least five,
#  Dumbledore,
#  Borrowed Item,
#  Dumbledore,
#  Young Sirius Black,
#  Item,
#  Muggles,
#  Bristol board,
#  Dumbledore,
#  McGonagall,
#  McGonagall,
#  Dumbledore,
#  Item,
#  Dumbledore,
#  one,
#  the London Underground,
#  Dumbledore,
#  Harry,
#  Dursleys,
#  Hagrid,
#  Harry,
#  que,
#  Hagrid,
#  Shhh,
#  McGonagall,
#  Hagrid,
#  Item,
#  Item - Lily,
#  James,
#  Harry,
#  Hagrid,
#  McGonagall,
#  Harry,
#  Item,
#  Harry,
#  two,
#  three,
#  Hagrid,
#  McGonagall,
#  Dumbledore,
#  Dumbledore,
#  Hagrid,
#  McGonagall,
#  Dumbledore,
#  Hagrid,
#  Item,
#  the night,
#  McGonagall,
#  Dumbledore,
#  McGonagall,
#  Dumbledore,
#  Put-Outer,
#  Item,
#  twelve,
#  Privet,
#  four,
#  Harry,
#  Privet Drive,
#  Harry Potter,
#  One,
#  to few hours',
#  Dursley,
#  the next few weeks,
#  Dudley,
#  Este,
#  Harry Potter - the,
#  quien)

# %%
np.unique(np.array(sp_person_outputs[lib_key]))
# Out:
# array([Dursley, Dursley, Dursley, Dursleys, Dudley, Dursleys, Dursley,
#        Dursley, Dursley, Dursley, Dursley, Dursley, Dursley, Dudley,
#        Dudley, Dursley, Dursley, Dursley, Dursley, Privet Drive, Dursley,
#        Dursley, Dursley, Dursley, Dursley, Dursley, Dursley, baker, Harry,
#        Dursley, Harry, Harry, Harold, Dursley, Dursley, last!Even Muggles,
#        Dursley, Dursley, Shoo, Dursley, Dursley, Dursley, Next Door,
#        Dudley, Dursley, Dudley, Jim McGuffin, Jim, Ted, Kent, Yorkshire,
#        Bonfire Night, Dursley, Dursley, Dursley, Dursley, Dursley,
#        Dursley, Dursley, Dudley, Dursley, Harry, Dursley, Dursley,
#        Dursley, Dursley, Dursley, Dursley, Dursley, Privet,
#        Albus Dumbledore, Albus Dumbledore, Dursley, Dumbledore, Item,
#        McGonagall, Item, quien, Item, McGonagall, McGonagall, Item,
#        Flocks, Kent, Dumbledore, McGonagall, Item, Dumbledore, Muggle,
#        McGonagall, Este, McGonagall, quien, McGonagall, Dumbledore,
#        Pomfrey, McGonagall, Item, McGonagall, Discuss, Dumbledore, Item,
#        Item, Dumbledore, Dumbledore, Voldemort, Lily, James Potter,
#        Dumbledore, McGonagall, Lily, James, Item, Item, Dumbledore,
#        McGonagall, Harry Potter, Dumbledore, McGonagall, Harry,
#        Dumbledore, McGonagall, Dumbledore, Item, Item, Item, Hagrid, Item,
#        quien, McGonagall, Harry, quien, McGonagall, quien, Harry Potter,
#        Dumbledore, McGonagall, Harry, Dumbledore, McGonagall, Dumbledore,
#        Harry underneath Item, Hagrid, Dumbledore, McGonagall, Item, Item,
#        Item, Dumbledore, Dumbledore, Item, Muggles, Dumbledore,
#        McGonagall, McGonagall, Dumbledore, Dumbledore, Harry, Dursleys,
#        Hagrid, Harry, que, Hagrid, Shhh, McGonagall, Hagrid, James, Harry,
#        Hagrid, McGonagall, Harry, Harry, Hagrid, McGonagall, Dumbledore,
#        Dumbledore, Hagrid, McGonagall, Dumbledore, Hagrid, McGonagall,
#        Dumbledore, McGonagall, Dumbledore, Put-Outer, Item, Harry,
#        Harry Potter, Dursley, Dudley, Este, Harry Potter - the, quien],
#       dtype=object)

# %%
spacy_locations = []
for doc in nlp.pipe([ttext]):
    for ent in doc.ents:
        if ent.label_ == 'LOCATION':
            spacy_locations.append(ent)

# %%
spacy_locations
# Out:
# []

# %% [markdown]
# ## NLTK

# %%
st = NERTagger('../../../StanfordNER/classifiers/english.all.3class.distsim.crf.ser.gz', '../../../StanfordNER/stanford-ner.jar')

# %%
lib_key = 'nltk'
st_person_outputs[lib_key] = []
errors = []

text = ''.join(char for char in ttext if ord(char) < 128)
for sent in nltk.sent_tokenize(text):
    tokens = nltk.tokenize.word_tokenize(sent)
    try:
        tags = st.tag(tokens)
    except Exception:
        print(*tokens)
        print()
        errors.append(tokens)
    else:
        for tag in tags:
            if tag[1] == 'PERSON':
                person_outputs[lib_key].append(tag)

# %%
person_outputs['nltk']
# Out:
# [('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursleys', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harvey', 'PERSON'),
#  ('Harold', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Next', 'PERSON'),
#  ('Door', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Jim', 'PERSON'),
#  ('McGuffin', 'PERSON'),
#  ('Jim', 'PERSON'),
#  ('Ted', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Howard', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Petunia', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Albus', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Albus', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall.', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dedalus', 'PERSON'),
#  ('Diggle', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('YouKnow-Who', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Este', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Voldemort', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Voldemort', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Voldemort', 'PERSON'),
#  ('Madam', 'PERSON'),
#  ('Pomfrey', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Voldemort', 'PERSON'),
#  ('Godric', 'PERSON'),
#  ('Lily', 'PERSON'),
#  ('James', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Lily', 'PERSON'),
#  ('James', 'PERSON'),
#  ('Albus', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('James', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Hagrid', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('McGonagall', 'PERSON'),
#  ('Dumbledore', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Potter', 'PERSON'),
#  ('Dursley', 'PERSON'),
#  ('Dudley', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Potter', 'PERSON')]

# %%
nltk_locations = []
for sent in nltk.sent_tokenize(text):
    tokens = nltk.tokenize.word_tokenize(sent)
    tags = st.tag(tokens)
    for tag in tags:
        if tag[1] == 'LOCATION':
            nltk_locations.append(tag)

# %%
nltk_locations
# Out:
# [('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('Kent', 'LOCATION'),
#  ('Yorkshire', 'LOCATION'),
#  ('Britain', 'LOCATION'),
#  ('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('London', 'LOCATION'),
#  ('Underground', 'LOCATION'),
#  ('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('Privet', 'LOCATION'),
#  ('Drive', 'LOCATION'),
#  ('Este', 'LOCATION')]

# %% [markdown]
# ## Flair

# %%
tagger = SequenceTagger.load('ner')
# Out:
# 2020-01-05 12:26:21,407 loading file C:\Users\aland\.flair\models\en-ner-conll03-v0.4.pt

# %%
lib_key = 'flair'
person_outputs[lib_key] = []
sentences = [sent for sent in split_single(ttext)]
for sent in sentences:
    sent = Sentence(sent)
    tagger.predict(sent)
    for entity in sent.get_spans('ner'):
        if entity.tag == 'PER':
            person_outputs[lib_key].append(entity)
# Out:
# 2020-01-05 12:29:22,193 ACHTUNG: An empty Sentence was created! Are there empty strings in your dataset?
# 2020-01-05 12:29:22,194 Ignore 1 sentence(s) with no tokens.

# %%
person_outputs[lib_key]
# Out:
# [<PER-span (3,4): "Mrs. Dursley,">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursleys">,
#  <PER-span (8): "Dudley">,
#  <PER-span (1): "Potter">,
#  <PER-span (4): "Dursley's">,
#  <PER-span (4): "Dursley">,
#  <PER-span (1): "Dudley">,
#  <PER-span (5): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (4): "Dursley">,
#  <PER-span (1): "Dudley">,
#  <PER-span (6): "Dursley">,
#  <PER-span (1): "Dursley">,
#  <PER-span (9): "Dudley">,
#  <PER-span (2): "Dudley">,
#  <PER-span (5): "Dursley">,
#  <PER-span (5): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (3): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (6): "Dursley">,
#  <PER-span (1): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley,">,
#  <PER-span (1): "He'd">,
#  <PER-span (12): "Harry"">,
#  <PER-span (2): "Dursley">,
#  <PER-span (1): "Potter">,
#  <PER-span (5): "Potter">,
#  <PER-span (11): "Harry.">,
#  <PER-span (11): "Harry.">,
#  <PER-span (1): "He'd">,
#  <PER-span (5): "Harvey.">,
#  <PER-span (4): "Dursley;">,
#  <PER-span (7): "Dursley">,
#  <PER-span (7): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (9): "Muggle,">,
#  <PER-span (4): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (3,4): "Next Door's">,
#  <PER-span (11): "Dudley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (1): "Dudley">,
#  <PER-span (5,6): "Jim McGuffin">,
#  <PER-span (1,2): ""Well, Ted,"">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (1): "He'd">,
#  <PER-span (6): "Dursley">,
#  <PER-span (7): "Dursley">,
#  <PER-span (4): "Dursley.">,
#  <PER-span (2): "Dursley">,
#  <PER-span (2): "Dursley">,
#  <PER-span (4): "Dudley's">,
#  <PER-span (6): "Dursley">,
#  <PER-span (5): "Dursley,">,
#  <PER-span (3): "Dursley">,
#  <PER-span (9): "Dursley">,
#  <PER-span (1): "Potters?">,
#  <PER-span (2): "Dursley">,
#  <PER-span (1): "Dursley">,
#  <PER-span (1): "Dursley.">,
#  <PER-span (9): "Petunia">,
#  <PER-span (7): "Petunia">,
#  <PER-span (2): "Dursley">,
#  <PER-span (5,6): "Albus Dumbledore.">,
#  <PER-span (1,2): "Albus Dumbledore">,
#  <PER-span (2): "Dursley,">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (6): "McGonagall.">,
#  <PER-span (2): "McGonagall.">,
#  <PER-span (2): "McGonagall">,
#  <PER-span (7): "I'll">,
#  <PER-span (3,4): "Dedalus Diggle.">,
#  <PER-span (8): "Dumbledore">,
#  <PER-span (7): "McGonagall">,
#  <PER-span (8): "Dumbledore">,
#  <PER-span (12): "YouKnow-Who">,
#  <PER-span (4): "Dumbledore?">,
#  <PER-span (7): "Dumbledore.">,
#  <PER-span (1): "They're">,
#  <PER-span (8): "McGonagall">,
#  <PER-span (2): "Este">,
#  <PER-span (3): "McGonagall">,
#  <PER-span (6): "'You-Know-Who.'">,
#  <PER-span (6): "Voldemort's">,
#  <PER-span (8): "McGonagall,">,
#  <PER-span (8): "Voldemort,">,
#  <PER-span (6): "Dumbledore">,
#  <PER-span (8,9): "Madam Pomfrey">,
#  <PER-span (2): "McGonagall">,
#  <PER-span (8): "Dumbledore">,
#  <PER-span (6): "McGonagall">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (1): "Dumbledore,">,
#  <PER-span (12): "Voldemort">,
#  <PER-span (2): "Lily">,
#  <PER-span (4,5): "James Potter">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (2): "McGonagall">,
#  <PER-span (1): ""Lily">,
#  <PER-span (3): "James...">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (2): "McGonagall's">,
#  <PER-span (1): "They're">,
#  <PER-span (12): "Harry.">,
#  <PER-span (11,12,13): "Harry Potter, Voldemort's">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (4): "McGonagall.">,
#  <PER-span (5): "Harry">,
#  <PER-span (7): "Dumbledore.">,
#  <PER-span (2): "McGonagall">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (7): "Dumbledore,">,
#  <PER-span (11): ""Hagrid's">,
#  <PER-span (7): "McGonagall.">,
#  <PER-span (5): "Harry">,
#  <PER-span (2): "McGonagall,">,
#  <PER-span (1,2): "Harry Potter">,
#  <PER-span (9): "Dumbledore">,
#  <PER-span (4): "McGonagall">,
#  <PER-span (1): "He'll">,
#  <PER-span (13,14): "Harry Potter">,
#  <PER-span (11): "Harry">,
#  <PER-span (4): "Dumbledore,">,
#  <PER-span (2): "McGonagall">,
#  <PER-span (3): "Dumbledore?">,
#  <PER-span (7): "Harry">,
#  <PER-span (9): "Hagrid">,
#  <PER-span (4): "Hagrid">,
#  <PER-span (10): "Dumbledore.">,
#  <PER-span (1): "McGonagall">,
#  <PER-span (4): "Dumbledore,">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (4): "McGonagall">,
#  <PER-span (4): "McGonagall.">,
#  <PER-span (6): "Dumbledore.">,
#  <PER-span (7,8): "Item, Dumbledore?">,
#  <PER-span (5): "Hagrid">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (3): "Harry">,
#  <PER-span (3): "Hagrid.">,
#  <PER-span (5): "Harry">,
#  <PER-span (3): "Hagrid">,
#  <PER-span (4): "McGonagall,">,
#  <PER-span (4): "Hagrid,">,
#  <PER-span (7): "Lily">,
#  <PER-span (10): "James">,
#  <PER-span (6): "Harry">,
#  <PER-span (18): "Hagrid,">,
#  <PER-span (6): "McGonagall">,
#  <PER-span (9): "Hagrid">,
#  <PER-span (5): "Dumbledore">,
#  <PER-span (4): "Harry">,
#  <PER-span (7): "Harry's">,
#  <PER-span (4): "Hagrid's">,
#  <PER-span (7,8): "Professor McGonagall">,
#  <PER-span (4): "Dumbledore">,
#  <PER-span (1): "We've">,
#  <PER-span (4): "Hagrid">,
#  <PER-span (3): "McGonagall">,
#  <PER-span (6): "Dumbledore,">,
#  <PER-span (9): "Hagrid">,
#  <PER-span (9): "McGonagall,">,
#  <PER-span (12): "Dumbledore,">,
#  <PER-span (2): "McGonagall">,
#  <PER-span (1): "Dumbledore">,
#  <PER-span (3): "Harry,">,
#  <PER-span (1,2): "Harry Potter">,
#  <PER-span (1): "Dursley's">,
#  <PER-span (5): "Dudley...">,
#  <PER-span (9,10): "Harry Potter">]

# %%
flair_locations = []
for sent in sentences:
    sent = Sentence(sent)
    tagger.predict(sent)
    for entity in sent.get_spans('ner'):
        if entity.tag == 'LOC':
            flair_locations.append(entity)
# Out:
# 2020-01-05 12:32:08,176 ACHTUNG: An empty Sentence was created! Are there empty strings in your dataset?
# 2020-01-05 12:32:08,177 Ignore 1 sentence(s) with no tokens.

# %%
flair_locations
# Out:
# [<LOC-span (11): "Privet">,
#  <LOC-span (5): "Grunnings">,
#  <LOC-span (2): "Harold.">,
#  <LOC-span (9): "Jim?"">,
#  <LOC-span (5): "Britain?">,
#  <LOC-span (5,6): "Privet Drive">,
#  <LOC-span (10,11): "Privet Drive.">,
#  <LOC-span (5): "Dursleys'">,
#  <LOC-span (5): "Kent">,
#  <LOC-span (5): "SW">,
#  <LOC-span (4,5): "Godric's Hollow.">,
#  <LOC-span (1): "Este?">,
#  <LOC-span (4): "Bristol">,
#  <LOC-span (12): "London">,
#  <LOC-span (11): "Dursleys'">,
#  <LOC-span (8,9): "Privet Drive,">,
#  <LOC-span (8): "Este">]
